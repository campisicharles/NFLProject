# %%
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
import pandas as pd
import numpy as np
import os

# %%
Game_Data = pd.read_csv('Game_Data2.csv')
Game_Data.head()
# Out:
#    Year  Week HomeTeam AwayTeam  HomeScore  AwayScore  PointDiff  HWHL  \
# 0  2019     6       GB      DET         23         22          1     0
# 1  2019     6       SD      PIT         17         24         -7     1
# 2  2019     6      DEN      TEN         16          0         16     0
# 3  2019     6      NYJ      DAL         24         22          2     0
# 4  2019     6      ARI      ATL         34         33          1     0
#
#    Covered  HomeLine  ...  HOME_DefRushDVOA  HOME_STDVOA  VISIT_TotalDVOA  \
# 0        0      -6.0  ...            -0.221        2.000           -0.013
# 1        0      -5.5  ...            -0.069       -0.062            0.025
# 2        1      -2.5  ...            -0.628        0.085           -0.577
# 3        1       8.5  ...            -0.158        0.080            0.048
# 4        1       2.0  ...             0.033       -0.023           -0.026
#
#    VISIT_OffenseDVOA  VISIT_OffPassDVOA  VISIT_OffRushDVOA  VISIT_DefenseDVOA  \
# 0             -0.246              0.026             -0.375             -0.014
# 1             -0.056              0.161             -0.163             -0.050
# 2             -0.724             -0.562             -0.692             -0.194
# 3              0.289              0.486              0.077              0.276
# 4              0.326              0.662             -0.034              0.337
#
#    VISIT_DefPassDVOA  VISIT_DefRushDVOA  VISIT_STDVOA
# 0             -0.057              0.049         0.219
# 1              0.069             -0.399         0.031
# 2             -0.179             -0.210        -0.047
# 3              0.467             -0.086         0.036
# 4              0.802             -0.243        -0.015
#
# [5 rows x 29 columns]

# %%
target = Game_Data["HWHL"]
target_names = ["HW", "HL"]

# %%
data = Game_Data[['HomeLine', 'PredictTotal', 'HOME_OffPassDVOA', 'HOME_OffRushDVOA', 'HOME_DefPassDVOA', 'HOME_DefRushDVOA', 'HOME_STDVOA', 'VISIT_OffPassDVOA', 'VISIT_OffRushDVOA', 'VISIT_DefPassDVOA', 'VISIT_DefRushDVOA', 'VISIT_STDVOA' ]]
feature_names = data.columns 
data.head()
# Out:
#    HomeLine  PredictTotal  HOME_OffPassDVOA  HOME_OffRushDVOA  \
# 0      -6.0          46.5             0.117             0.270
# 1      -5.5          43.5             0.219            -0.407
# 2      -2.5          39.5            -0.286            -0.127
# 3       8.5          43.5             0.328            -0.161
# 4       2.0          51.0             0.564            -0.075
#
#    HOME_DefPassDVOA  HOME_DefRushDVOA  HOME_STDVOA  VISIT_OffPassDVOA  \
# 0            -0.189            -0.221        2.000              0.026
# 1             0.156            -0.069       -0.062              0.161
# 2            -0.463            -0.628        0.085             -0.562
# 3             0.214            -0.158        0.080              0.486
# 4             0.788             0.033       -0.023              0.662
#
#    VISIT_OffRushDVOA  VISIT_DefPassDVOA  VISIT_DefRushDVOA  VISIT_STDVOA
# 0             -0.375             -0.057              0.049         0.219
# 1             -0.163              0.069             -0.399         0.031
# 2             -0.692             -0.179             -0.210        -0.047
# 3              0.077              0.467             -0.086         0.036
# 4             -0.034              0.802             -0.243        -0.015

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(data, target, test_size=0.33, random_state=42)

# %%
# Support vector machine linear classifier
from sklearn.svm import SVC 
model = SVC(kernel='linear')

# %%
 # Create the GridSearch estimator along with a parameter object containing the values to adjust
from sklearn.model_selection import GridSearchCV
param_grid = {'C': [1, 5, 10],
              'gamma': [0.0001, 0.001, 0.01]}
grid = GridSearchCV(model, param_grid, verbose=3)

# %%
# Fit the model using the grid search estimator. 
# This will take the SVC model and try each combination of parameters
grid.fit(X_train, y_train)
# Out:
# C:\Users\ccampisi\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [CV] C=1, gamma=0.0001 ...............................................
# [CV] ...... C=1, gamma=0.0001, score=0.8311688311688312, total=   0.0s
# [CV] C=1, gamma=0.0001 ...............................................
# [CV] ...... C=1, gamma=0.0001, score=0.7956521739130434, total=   0.0s
# [CV] C=1, gamma=0.0001 ...............................................
# [CV] ...... C=1, gamma=0.0001, score=0.8296943231441049, total=   0.0s
# [CV] C=1, gamma=0.001 ................................................
# [CV] ....... C=1, gamma=0.001, score=0.8311688311688312, total=   0.0s
# [CV] C=1, gamma=0.001 ................................................
# [CV] ....... C=1, gamma=0.001, score=0.7956521739130434, total=   0.0s
# [CV] C=1, gamma=0.001 ................................................
# [CV] ....... C=1, gamma=0.001, score=0.8296943231441049, total=   0.0s
# [CV] C=1, gamma=0.01 .................................................
# [CV] ........ C=1, gamma=0.01, score=0.8311688311688312, total=   0.0s
# [CV] C=1, gamma=0.01 .................................................
# [CV] ........ C=1, gamma=0.01, score=0.7956521739130434, total=   0.0s
# [CV] C=1, gamma=0.01 .................................................
# [CV] ........ C=1, gamma=0.01, score=0.8296943231441049, total=   0.0s
# [CV] C=5, gamma=0.0001 ...............................................
# [CV] ...... C=5, gamma=0.0001, score=0.8441558441558441, total=   0.0s
# [CV] C=5, gamma=0.0001 ...............................................
# [CV] ....... C=5, gamma=0.0001, score=0.808695652173913, total=   0.0s
# [CV] C=5, gamma=0.0001 ...............................................
# [CV] ...... C=5, gamma=0.0001, score=0.8209606986899564, total=   0.0s
# [CV] C=5, gamma=0.001 ................................................
# [CV] ....... C=5, gamma=0.001, score=0.8441558441558441, total=   0.0s
# [CV] C=5, gamma=0.001 ................................................
# [CV] ........ C=5, gamma=0.001, score=0.808695652173913, total=   0.0s
# [CV] C=5, gamma=0.001 ................................................
# [CV] ....... C=5, gamma=0.001, score=0.8209606986899564, total=   0.0s
# [CV] C=5, gamma=0.01 .................................................
# [CV] ........ C=5, gamma=0.01, score=0.8441558441558441, total=   0.0s
# [CV] C=5, gamma=0.01 .................................................
# [CV] ......... C=5, gamma=0.01, score=0.808695652173913, total=   0.0s
# [CV] C=5, gamma=0.01 .................................................
# [CV] ........ C=5, gamma=0.01, score=0.8209606986899564, total=   0.0s
# [CV] C=10, gamma=0.0001 ..............................................
# [CV] ..... C=10, gamma=0.0001, score=0.8528138528138528, total=   0.1s
# [CV] C=10, gamma=0.0001 ..............................................
# [CV] ...... C=10, gamma=0.0001, score=0.808695652173913, total=   0.0s
# [CV] C=10, gamma=0.0001 ..............................................
# [CV] ..... C=10, gamma=0.0001, score=0.8253275109170306, total=   0.0s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ...... C=10, gamma=0.001, score=0.8528138528138528, total=   0.1s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ....... C=10, gamma=0.001, score=0.808695652173913, total=   0.0s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ...... C=10, gamma=0.001, score=0.8253275109170306, total=   0.0s
# [CV] C=10, gamma=0.01 ................................................
# [CV] ....... C=10, gamma=0.01, score=0.8528138528138528, total=   0.1s
# [CV] C=10, gamma=0.01 ................................................
# [CV] ........ C=10, gamma=0.01, score=0.808695652173913, total=   0.0s
# [CV] C=10, gamma=0.01 ................................................
# [CV] ....... C=10, gamma=0.01, score=0.8253275109170306, total=   0.0s
# [Parallel(n_jobs=1)]: Done  27 out of  27 | elapsed:    2.3s finished
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#        estimator=SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='linear', max_iter=-1, probability=False, random_state=None,
#   shrinking=True, tol=0.001, verbose=False),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid={'C': [1, 5, 10], 'gamma': [0.0001, 0.001, 0.01]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=3)

# %%
# List the best parameters for this dataset
print(grid.best_params_)
# Out:
# {'C': 10, 'gamma': 0.0001}

# %%
# List the best score
print(grid.best_score_)
# Out:
# 0.8289855072463768

# %%
 # Make predictions with the hypertuned model
predictions = grid.predict(X_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, predictions,
                            target_names=["HW", "HL"]))
# Out:
#               precision    recall  f1-score   support
#
#           HW       0.87      0.84      0.85       195
#           HL       0.79      0.83      0.81       145
#
#    micro avg       0.83      0.83      0.83       340
#    macro avg       0.83      0.83      0.83       340
# weighted avg       0.83      0.83      0.83       340

# %%
pd.DataFrame({"Prediction": predictions, "Actual": y_test}).reset_index(drop=True)
# Out:
#      Prediction  Actual
# 0             1       1
# 1             1       1
# 2             0       0
# 3             0       0
# 4             1       1
# 5             0       0
# 6             1       1
# 7             1       1
# 8             0       0
# 9             0       0
# 10            0       0
# 11            0       1
# 12            1       1
# 13            1       1
# 14            1       0
# 15            0       0
# 16            1       1
# 17            0       1
# 18            0       0
# 19            1       1
# 20            0       0
# 21            1       1
# 22            0       0
# 23            1       1
# 24            0       0
# 25            1       1
# 26            0       0
# 27            1       1
# 28            1       1
# 29            0       0
# ..          ...     ...
# 310           0       0
# 311           1       1
# 312           0       0
# 313           1       0
# 314           1       1
# 315           1       1
# 316           0       0
# 317           1       0
# 318           0       0
# 319           0       0
# 320           1       1
# 321           1       0
# 322           1       1
# 323           0       0
# 324           1       1
# 325           0       0
# 326           1       0
# 327           0       0
# 328           1       1
# 329           1       1
# 330           0       0
# 331           1       1
# 332           1       1
# 333           1       0
# 334           0       0
# 335           0       0
# 336           0       0
# 337           1       1
# 338           1       0
# 339           1       1
#
# [340 rows x 2 columns]

# %%
Week7 =

# %%
predictions = grid.predict(thursX)
print(predictions)
# Out:
# ['HL']
