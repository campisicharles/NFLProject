# %%
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
import pandas as pd
import numpy as np
import os

# %%
Game_Data = pd.read_csv('Game_Data2.csv')
Game_Data.head()
# Out:
#    Year  Week HomeTeam AwayTeam  HomeScore  AwayScore  PointDiff HWHL  \
# 0  2019     5       KC      IND         13         19         -6   HL
# 1  2019     5      DAL       GB         24         34        -10   HL
# 2  2019     5      CIN      ARI         23         26         -3   HL
# 3  2019     5      HOU      ATL         53         32         21   HW
# 4  2019     4      BAL      CLE         25         40        -15   HL
#
#    HomeLine  AwayLine  ...  HOME_DefRushDVOA  HOME_STDVOA  VISIT_TotalDVOA  \
# 0     -10.0      10.0  ...             0.011        0.005            0.338
# 1      -4.0       4.0  ...             0.204       -0.174            0.189
# 2      -4.0       4.0  ...             0.262        0.045           -0.108
# 3      -4.5       4.5  ...            -0.271       -0.043           -0.511
# 4      -5.5       5.5  ...             0.364        0.079            0.374
#
#    VISIT_OffenseDVOA  VISIT_OffPassDVOA  VISIT_OffRushDVOA  VISIT_DefenseDVOA  \
# 0              0.034              0.078              0.011             -0.233
# 1              0.176              0.184              0.290              0.033
# 2              0.231              0.196              0.406              0.249
# 3             -0.003              0.207             -0.265              0.471
# 4              0.344              0.403              0.451             -0.007
#
#    VISIT_DefPassDVOA  VISIT_DefRushDVOA  VISIT_STDVOA
# 0             -0.211             -0.291         0.070
# 1              0.042              0.018         0.045
# 2              0.392              0.031        -0.089
# 3              1.143             -0.146        -0.037
# 4             -0.016              0.002         0.023
#
# [5 rows x 28 columns]

# %%
target = Game_Data["HWHL"]
target_names = ["HW", "HL"]

# %%
data = Game_Data[['HomeLine', 'PredictTotal', 'HOME_OffPassDVOA', 'HOME_OffRushDVOA', 'HOME_DefPassDVOA', 'HOME_DefRushDVOA', 'HOME_STDVOA', 'VISIT_OffPassDVOA', 'VISIT_OffRushDVOA', 'VISIT_DefPassDVOA', 'VISIT_DefRushDVOA', 'VISIT_STDVOA' ]]
feature_names = data.columns 
data.head()
# Out:
#    HomeLine  PredictTotal  HOME_OffPassDVOA  HOME_OffRushDVOA  \
# 0     -10.0          57.0             0.007            -0.334
# 1      -4.0          48.0             0.269             0.068
# 2      -4.0          48.0             0.380            -0.133
# 3      -4.5          48.5             1.120            -0.083
# 4      -5.5          46.5            -0.042            -0.016
#
#    HOME_DefPassDVOA  HOME_DefRushDVOA  HOME_STDVOA  VISIT_OffPassDVOA  \
# 0            -0.039             0.011        0.005              0.078
# 1             0.119             0.204       -0.174              0.184
# 2             0.379             0.262        0.045              0.196
# 3             0.127            -0.271       -0.043              0.207
# 4             0.487             0.364        0.079              0.403
#
#    VISIT_OffRushDVOA  VISIT_DefPassDVOA  VISIT_DefRushDVOA  VISIT_STDVOA
# 0              0.011             -0.211             -0.291         0.070
# 1              0.290              0.042              0.018         0.045
# 2              0.406              0.392              0.031        -0.089
# 3             -0.265              1.143             -0.146        -0.037
# 4              0.451             -0.016              0.002         0.023

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(data, target, test_size=0.33, random_state=42)

# %%
# Support vector machine linear classifier
from sklearn.svm import SVC 
model = SVC(kernel='linear')

# %%
 # Create the GridSearch estimator along with a parameter object containing the values to adjust
from sklearn.model_selection import GridSearchCV
param_grid = {'C': [1, 5, 10],
              'gamma': [0.0001, 0.001, 0.01]}
grid = GridSearchCV(model, param_grid, verbose=3)

# %%
# Fit the model using the grid search estimator. 
# This will take the SVC model and try each combination of parameters
grid.fit(X_train, y_train)
# Out:
# C:\Users\ccampisi\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [CV] C=1, gamma=0.0001 ...............................................
# [CV] ...... C=1, gamma=0.0001, score=0.8245614035087719, total=   0.0s
# [CV] C=1, gamma=0.0001 ...............................................
# [CV] ...... C=1, gamma=0.0001, score=0.8451327433628318, total=   0.0s
# [CV] C=1, gamma=0.0001 ...............................................
# [CV] ...... C=1, gamma=0.0001, score=0.8716814159292036, total=   0.0s
# [CV] C=1, gamma=0.001 ................................................
# [CV] ....... C=1, gamma=0.001, score=0.8245614035087719, total=   0.0s
# [CV] C=1, gamma=0.001 ................................................
# [CV] ....... C=1, gamma=0.001, score=0.8451327433628318, total=   0.0s
# [CV] C=1, gamma=0.001 ................................................
# [CV] ....... C=1, gamma=0.001, score=0.8716814159292036, total=   0.0s
# [CV] C=1, gamma=0.01 .................................................
# [CV] ........ C=1, gamma=0.01, score=0.8245614035087719, total=   0.0s
# [CV] C=1, gamma=0.01 .................................................
# [CV] ........ C=1, gamma=0.01, score=0.8451327433628318, total=   0.0s
# [CV] C=1, gamma=0.01 .................................................
# [CV] ........ C=1, gamma=0.01, score=0.8716814159292036, total=   0.0s
# [CV] C=5, gamma=0.0001 ...............................................
# [CV] ...... C=5, gamma=0.0001, score=0.8201754385964912, total=   0.0s
# [CV] C=5, gamma=0.0001 ...............................................
# [CV] ...... C=5, gamma=0.0001, score=0.8451327433628318, total=   0.0s
# [CV] C=5, gamma=0.0001 ...............................................
# [CV] ...... C=5, gamma=0.0001, score=0.8761061946902655, total=   0.0s
# [CV] C=5, gamma=0.001 ................................................
# [CV] ....... C=5, gamma=0.001, score=0.8201754385964912, total=   0.0s
# [CV] C=5, gamma=0.001 ................................................
# [CV] ....... C=5, gamma=0.001, score=0.8451327433628318, total=   0.0s
# [CV] C=5, gamma=0.001 ................................................
# [CV] ....... C=5, gamma=0.001, score=0.8761061946902655, total=   0.0s
# [CV] C=5, gamma=0.01 .................................................
# [CV] ........ C=5, gamma=0.01, score=0.8201754385964912, total=   0.0s
# [CV] C=5, gamma=0.01 .................................................
# [CV] ........ C=5, gamma=0.01, score=0.8451327433628318, total=   0.0s
# [CV] C=5, gamma=0.01 .................................................
# [CV] ........ C=5, gamma=0.01, score=0.8761061946902655, total=   0.0s
# [CV] C=10, gamma=0.0001 ..............................................
# [CV] ..... C=10, gamma=0.0001, score=0.8245614035087719, total=   0.0s
# [CV] C=10, gamma=0.0001 ..............................................
# [CV] ..... C=10, gamma=0.0001, score=0.8362831858407079, total=   0.0s
# [CV] C=10, gamma=0.0001 ..............................................
# [CV] ..... C=10, gamma=0.0001, score=0.8761061946902655, total=   0.0s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ...... C=10, gamma=0.001, score=0.8245614035087719, total=   0.0s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ...... C=10, gamma=0.001, score=0.8362831858407079, total=   0.0s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ...... C=10, gamma=0.001, score=0.8761061946902655, total=   0.0s
# [CV] C=10, gamma=0.01 ................................................
# [CV] ....... C=10, gamma=0.01, score=0.8245614035087719, total=   0.0s
# [CV] C=10, gamma=0.01 ................................................
# [CV] ....... C=10, gamma=0.01, score=0.8362831858407079, total=   0.0s
# [CV] C=10, gamma=0.01 ................................................
# [CV] ....... C=10, gamma=0.01, score=0.8761061946902655, total=   0.1s
# [Parallel(n_jobs=1)]: Done  27 out of  27 | elapsed:    2.0s finished
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#        estimator=SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='linear', max_iter=-1, probability=False, random_state=None,
#   shrinking=True, tol=0.001, verbose=False),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid={'C': [1, 5, 10], 'gamma': [0.0001, 0.001, 0.01]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=3)

# %%
# List the best parameters for this dataset
print(grid.best_params_)
# Out:
# {'C': 1, 'gamma': 0.0001}

# %%
# List the best score
print(grid.best_score_)
# Out:
# 0.8470588235294118

# %%
 # Make predictions with the hypertuned model
predictions = grid.predict(X_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, predictions,
                            target_names=["HW", "HL"]))
# Out:
#               precision    recall  f1-score   support
#
#           HW       0.72      0.81      0.76       132
#           HL       0.87      0.80      0.83       204
#
#    micro avg       0.80      0.80      0.80       336
#    macro avg       0.79      0.80      0.80       336
# weighted avg       0.81      0.80      0.81       336

# %%
pd.DataFrame({"Prediction": predictions, "Actual": y_test}).reset_index(drop=True)
# Out:
#     Prediction Actual
# 0           HW     HW
# 1           HL     HL
# 2           HL     HL
# 3           HL     HL
# 4           HL     HL
# 5           HW     HW
# 6           HW     HW
# 7           HL     HL
# 8           HW     HW
# 9           HL     HW
# 10          HW     HW
# 11          HL     HL
# 12          HW     HL
# 13          HL     HL
# 14          HL     HL
# 15          HW     HL
# 16          HW     HW
# 17          HW     HW
# 18          HW     HW
# 19          HW     HW
# 20          HW     HW
# 21          HW     HW
# 22          HW     HW
# 23          HL     HL
# 24          HL     HL
# 25          HL     HW
# 26          HL     HL
# 27          HL     HW
# 28          HL     HL
# 29          HW     HW
# ..         ...    ...
# 306         HW     HW
# 307         HW     HW
# 308         HW     HW
# 309         HL     HL
# 310         HL     HW
# 311         HW     HW
# 312         HW     HW
# 313         HW     HW
# 314         HW     HW
# 315         HL     HW
# 316         HW     HW
# 317         HL     HL
# 318         HW     HW
# 319         HL     HL
# 320         HW     HW
# 321         HL     HL
# 322         HW     HW
# 323         HL     HL
# 324         HL     HW
# 325         HL     HL
# 326         HL     HL
# 327         HL     HW
# 328         HW     HW
# 329         HL     HL
# 330         HW     HW
# 331         HL     HW
# 332         HW     HW
# 333         HW     HW
# 334         HL     HL
# 335         HW     HW
#
# [336 rows x 2 columns]

# %%
thursX = [[4.5,50.5,-0.1585,0.0125,0.201,-0.16775,-0.06975,0.4765,-0.22075,-0.107,0.076,-0.033]]

# %%
predictions = grid.predict(thursX)
print(predictions)
# Out:
# ['HL']
