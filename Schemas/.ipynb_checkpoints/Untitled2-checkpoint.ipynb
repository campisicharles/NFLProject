# %%
import matplotlib.pyplot as plt
import pandas as pd
import os

# %%
Game_Data = pd.read_csv('Game_Data2.csv')
Game_Data.head()
# Out:
#    Year  Week HomeTeam AwayTeam  HomeScore  AwayScore  PointDiff HWHL  \
# 0  2019     5       KC      IND         13         19         -6   HL
# 1  2019     5      DAL       GB         24         34        -10   HL
# 2  2019     5      CIN      ARI         23         26         -3   HL
# 3  2019     5      HOU      ATL         53         32         21   HW
# 4  2019     4      BAL      CLE         25         40        -15   HL
#
#    HomeLine  AwayLine  ...  HOME_DefRushDVOA  HOME_STDVOA  VISIT_TotalDVOA  \
# 0     -10.0      10.0  ...             0.011        0.005            0.338
# 1      -4.0       4.0  ...             0.204       -0.174            0.189
# 2      -4.0       4.0  ...             0.262        0.045           -0.108
# 3      -4.5       4.5  ...            -0.271       -0.043           -0.511
# 4      -5.5       5.5  ...             0.364        0.079            0.374
#
#    VISIT_OffenseDVOA  VISIT_OffPassDVOA  VISIT_OffRushDVOA  VISIT_DefenseDVOA  \
# 0              0.034              0.078              0.011             -0.233
# 1              0.176              0.184              0.290              0.033
# 2              0.231              0.196              0.406              0.249
# 3             -0.003              0.207             -0.265              0.471
# 4              0.344              0.403              0.451             -0.007
#
#    VISIT_DefPassDVOA  VISIT_DefRushDVOA  VISIT_STDVOA
# 0             -0.211             -0.291         0.070
# 1              0.042              0.018         0.045
# 2              0.392              0.031        -0.089
# 3              1.143             -0.146        -0.037
# 4             -0.016              0.002         0.023
#
# [5 rows x 28 columns]

# %%
X = Game_Data[['HomeLine', 'PredictTotal', 'HOME_OffenseDVOA', 'HOME_OffPassDVOA', 'HOME_OffRushDVOA', 'HOME_DefPassDVOA', 'HOME_DefRushDVOA', 'HOME_STDVOA', 'VISIT_OffenseDVOA', 'VISIT_OffPassDVOA', 'VISIT_OffRushDVOA', 'VISIT_DefPassDVOA', 'VISIT_DefRushDVOA', 'VISIT_STDVOA' ]]
y = Game_Data['HWHL']
print(X.shape, y.shape)
# Out:
# (1016, 14) (1016,)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
          intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
          penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
          verbose=0, warm_start=False)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
 classifier.fit(X_train, y_train)
# Out:
# C:\Users\ccampisi\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
          intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
          penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
          verbose=0, warm_start=False)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
print(f"Training Data Score: {classifier.score(X_train, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test, y_test)}")
# Out:
# Training Data Score: 0.8544117647058823
# Testing Data Score: 0.8125

# %%
predictions = classifier.predict(X_test)
print(f"First 10 Predictions:   {predictions[:10]}")
print(f"First 10 Actual labels: {y_test[:10].values}")
# Out:
# First 10 Predictions:   ['HW' 'HL' 'HL' 'HL' 'HL' 'HW' 'HW' 'HL' 'HW' 'HL']
# First 10 Actual labels: ['HW' 'HL' 'HL' 'HL' 'HL' 'HW' 'HW' 'HL' 'HW' 'HW']

# %%
pd.DataFrame({"Prediction": predictions, "Actual": y_test}).reset_index(drop=True)
# Out:
#     Prediction Actual
# 0           HW     HW
# 1           HL     HL
# 2           HL     HL
# 3           HL     HL
# 4           HL     HL
# 5           HW     HW
# 6           HW     HW
# 7           HL     HL
# 8           HW     HW
# 9           HL     HW
# 10          HW     HW
# 11          HL     HL
# 12          HW     HL
# 13          HL     HL
# 14          HL     HL
# 15          HW     HL
# 16          HW     HW
# 17          HW     HW
# 18          HW     HW
# 19          HW     HW
# 20          HW     HW
# 21          HW     HW
# 22          HW     HW
# 23          HL     HL
# 24          HL     HL
# 25          HW     HW
# 26          HL     HL
# 27          HL     HW
# 28          HL     HL
# 29          HW     HW
# ..         ...    ...
# 306         HW     HW
# 307         HW     HW
# 308         HW     HW
# 309         HL     HL
# 310         HL     HW
# 311         HW     HW
# 312         HW     HW
# 313         HW     HW
# 314         HW     HW
# 315         HL     HW
# 316         HW     HW
# 317         HL     HL
# 318         HW     HW
# 319         HL     HL
# 320         HW     HW
# 321         HL     HL
# 322         HW     HW
# 323         HL     HL
# 324         HL     HW
# 325         HL     HL
# 326         HL     HL
# 327         HL     HW
# 328         HW     HW
# 329         HL     HL
# 330         HW     HW
# 331         HL     HW
# 332         HW     HW
# 333         HW     HW
# 334         HL     HL
# 335         HW     HW
#
# [336 rows x 2 columns]
