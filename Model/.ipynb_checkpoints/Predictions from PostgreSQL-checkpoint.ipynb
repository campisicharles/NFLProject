# %%
import numpy as np
import pandas as pd
from sklearn.externals import joblib

model1=joblib.load('John_Madden.joblib') 
model2=joblib.load('Shotgun.joblib') 
model3=joblib.load('Pro_Set.joblib') 
model4=joblib.load('Points.joblib')

# %%
import sqlalchemy as db

db_string = "postgres+psycopg2://postgres:Kelly12jim@bc-nfl-db.ciy15lpp3eog.us-east-2.rds.amazonaws.com:5432/postgres"
engine = db.create_engine(db_string)
connection = engine.connect()
metadata = db.MetaData()
NFL = db.Table('game_data', metadata, autoload=True, autoload_with=engine)

# %%
from sqlalchemy.orm import sessionmaker

Session = sessionmaker(bind=engine)
s = Session()

# %%
from sqlalchemy.ext.automap import automap_base
Base = automap_base()
Base.prepare(engine, reflect=True)
Base.classes.keys()

# %%
#DON'T RUN THIS, WIP




from sqlalchemy import Column, Integer, String, Float
class Game(Base):
    __tablename__ = 'game_data'
    __table_args__ = {'extend_existing':True}
    year = Column(Integer)
    week = Column(Integer)
    hometeam = Column(String)
    awayteam = Column(String)
    homescore = Column(Integer)
    awayscore = Column(Integer)
    pointdiff = Column(Float)
    hwhl = Column(Integer)
    covered= Column(Integer)
    homeline = Column(Float)
    awayline = Column(Float)
    predicttotal = Column(Float)
    actualtotal = Column(Integer)
    home_totaldvoa = Column(Float)
    home_offensedvoa = Column(Float)
    home_offpassdvoa = Column(Float)
    home_offrushdvoa = Column(Float)
    home_defensedvoa = Column(Float)
    home_defpassdvoa = Column(Float)
    home_defrushdvoa = Column(Float)
    home_stdvoa = Column(Float)
    visit_totaldvoa = Column(Float)
    visit_offensedvoa = Column(Float)
    visit_offpassdvoa = Column(Float)
    visit_offrushdvoa = Column(Float)
    visit_defensedvoa = Column(Float)
    visit_defpassdvoa = Column(Float)
    visit_defrushdvoa = Column(Float)
    visit_stdvoa = Column(Float)

# %%
homestats1 = s.query(NFL).filter_by(year=2019).filter_by(hometeam="DEN").all()
homestats2 = s.query(NFL).filter_by(year=2019).filter_by(awayteam="DEN").all()
homeOffPass= []
homeOffRush= []
homeDefPass= []
homeDefRush= []
homeST =[]

for i in range(len(homestats1)):
    homeOffPass.append(homestats1[i][23])
    homeOffRush.append(homestats1[i][24])
    homeDefPass.append(homestats1[i][26])
    homeDefRush.append(homestats1[i][27])
    homeST.append(homestats1[i][28])

for h in range(len(visitstats2)):
    homeOffPass.append(homestats2[h][23])
    homeOffRush.append(homestats2[h][24])
    homeDefPass.append(homestats2[h][26])
    homeDefRush.append(homestats2[h][27])
    homeST.append(homestats2[h][28])

visitstats1 = s.query(NFL).filter_by(year=2019).filter_by(hometeam="KC").all()
visitstats2 = s.query(NFL).filter_by(year=2019).filter_by(awayteam="KC").all()
visitOffPass= []
visitOffRush= []
visitDefPass= []
visitDefRush= []
visitST =[]

for i in range(len(visitstats1)):
    visitOffPass.append(visitstats1[i][23])
    visitOffRush.append(visitstats1[i][24])
    visitDefPass.append(visitstats1[i][26])
    visitDefRush.append(visitstats1[i][27])
    visitST.append(visitstats1[i][28])

for h in range(len(visitstats2)):
    visitOffPass.append(visitstats2[h][23])
    visitOffRush.append(visitstats2[h][24])
    visitDefPass.append(visitstats2[h][26])
    visitDefRush.append(visitstats2[h][27])
    visitST.append(visitstats2[h][28])

# %%
h1 = np.mean(homeOffPass)
h2 = np.mean(homeOffRush)
h3 = np.mean(homeDefPass)
h4 = np.mean(homeDefRush)
h5 = np.mean(homeST)

v1 = np.mean(visitOffPass)
v2 = np.mean(visitOffRush)
v3 = np.mean(visitDefPass)
v4 = np.mean(visitDefRush)
v5 = np.mean(visitST)

# %%
data = [['7','DEN','KC',4.5,50.5, h1 ,h2,h3,h4,h5,v1,v2,v3,v4,v5] ]
model_data = pd.DataFrame(data, columns = ['Week','Home','Away','HomeLine', 'PredictTotal', 'HOME_OFFPass_DVOA', 'HOME_OFFRush_DVOA', 'HOME_DEFPassDVOA', 'HOME_DEFRushDVOA','HOME_STDVOA', 'VISIT_OFFPass_DVOA', 'VISIT_OFFRush_DVOA', 'VISIT_DEFPassDVOA', 'VISIT_DEFRushDVOA','VISIT_STDVOA'])

# %%
homestats1 = s.query(NFL).filter_by(year=2019).filter_by(hometeam="GB").all()
homestats2 = s.query(NFL).filter_by(year=2019).filter_by(awayteam="GB").all()
homeOffPass= []
homeOffRush= []
homeDefPass= []
homeDefRush= []
homeST =[]

for i in range(len(homestats1)):
    homeOffPass.append(homestats1[i][23])
    homeOffRush.append(homestats1[i][24])
    homeDefPass.append(homestats1[i][26])
    homeDefRush.append(homestats1[i][27])
    homeST.append(homestats1[i][28])

for h in range(len(visitstats2)):
    homeOffPass.append(homestats2[h][23])
    homeOffRush.append(homestats2[h][24])
    homeDefPass.append(homestats2[h][26])
    homeDefRush.append(homestats2[h][27])
    homeST.append(homestats2[h][28])

visitstats1 = s.query(NFL).filter_by(year=2019).filter_by(hometeam="OAK").all()
visitstats2 = s.query(NFL).filter_by(year=2019).filter_by(awayteam="OAK").all()
visitOffPass= []
visitOffRush= []
visitDefPass= []
visitDefRush= []
visitST =[]

for i in range(len(visitstats1)):
    visitOffPass.append(visitstats1[i][23])
    visitOffRush.append(visitstats1[i][24])
    visitDefPass.append(visitstats1[i][26])
    visitDefRush.append(visitstats1[i][27])
    visitST.append(visitstats1[i][28])

for h in range(len(visitstats2)):
    visitOffPass.append(visitstats2[h][23])
    visitOffRush.append(visitstats2[h][24])
    visitDefPass.append(visitstats2[h][26])
    visitDefRush.append(visitstats2[h][27])
    visitST.append(visitstats2[h][28])

# %%
h1 = np.mean(homeOffPass)
h2 = np.mean(homeOffRush)
h3 = np.mean(homeDefPass)
h4 = np.mean(homeDefRush)
h5 = np.mean(homeST)

v1 = np.mean(visitOffPass)
v2 = np.mean(visitOffRush)
v3 = np.mean(visitDefPass)
v4 = np.mean(visitDefRush)
v5 = np.mean(visitST)

# %%
data = [['7','GB','OAK',-7,46, h1 ,h2,h3,h4,h5,v1,v2,v3,v4,v5] ]
temp_df = pd.DataFrame(data, columns = ['Week','Home','Away','HomeLine', 'PredictTotal', 'HOME_OFFPass_DVOA', 'HOME_OFFRush_DVOA', 'HOME_DEFPassDVOA', 'HOME_DEFRushDVOA','HOME_STDVOA', 'VISIT_OFFPass_DVOA', 'VISIT_OFFRush_DVOA', 'VISIT_DEFPassDVOA', 'VISIT_DEFRushDVOA','VISIT_STDVOA'])
model_data.append(temp_df, ignore_index= True)
# Out:
#   Week Home Away  HomeLine  PredictTotal                 HOME_OFFPass_DVOA  \
# 0    7  DEN   KC       4.5          50.5  -0.06233333333333333333333333333
# 1    7   GB  OAK      -7.0          46.0                            0.0508
#
#                   HOME_OFFRush_DVOA                HOME_DEFPassDVOA  \
# 0  -0.03866666666666666666666666667  0.4166666666666666666666666667
# 1                            0.0432                          0.0438
#
#                    HOME_DEFRushDVOA HOME_STDVOA VISIT_OFFPass_DVOA  \
# 0  -0.07866666666666666666666666667       0.013             0.3315
# 1                           -0.0886      0.0322             0.2128
#
#   VISIT_OFFRush_DVOA VISIT_DEFPassDVOA VISIT_DEFRushDVOA VISIT_STDVOA
# 0            0.03175          -0.02925          -0.11275     -0.01075
# 1            -0.1832            0.2168           -0.0336       -0.002
