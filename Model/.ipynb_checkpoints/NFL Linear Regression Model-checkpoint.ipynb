# %%
import numpy as np
import pandas as pd

# %%
game_data = pd.read_csv('Game_Data.csv')
game_data.head()
# Out:
#    Year  Week HomeTeam AwayTeam  HomeScore  AwayScore  PointDiff  HomeLine  \
# 0  2019     5       KC      IND         13         19         -6     -10.0
# 1  2015     2      CHI      ARI         23         48        -25       1.5
# 2  2019     5      DAL       GB         24         34        -10      -4.0
# 3  2015     5      DET      ARI         17         42        -25       2.5
# 4  2015     6      PIT      ARI         25         13         12       3.0
#
#    AwayLine  PredictTotal  ...  HOME_DefRushDVOA  HOME_STDVOA  \
# 0      10.0          57.0  ...             0.011        0.005
# 1      -1.5          44.5  ...             0.124       -0.150
# 2       4.0          48.0  ...             0.204       -0.174
# 3      -2.5          44.0  ...             0.601       -0.016
# 4      -3.0          44.0  ...            -0.357        0.109
#
#    VISIT_TotalDVOA  VISIT_OffenseDVOA  VISIT_OffPassDVOA  VISIT_OffRushDVOA  \
# ...

# %%
X = game_data[['HomeLine', 'PredictTotal', 'HOME_OffPassDVOA', 'HOME_OffRushDVOA', 'HOME_DefPassDVOA', 'HOME_DefRushDVOA', 'HOME_STDVOA', 'VISIT_OffPassDVOA', 'VISIT_OffRushDVOA', 'VISIT_DefPassDVOA', 'VISIT_DefRushDVOA', 'VISIT_STDVOA' ]]
y = game_data['PointDiff']
print(X.shape, y.shape)
# Out:
# (1016, 12) (1016,)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X, y)
score = model.score(X, y)
print(f"R2 Score: {score}")
# Out:
# R2 Score: 0.784646347814956

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
model = LinearRegression()

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=29)
model.fit(X_train, y_train)


MSE = mean_squared_error(y_train, model.predict(X_train))
r2 = model.score(X_train, y_train)
print(f"MSE: {MSE}, R2: {r2}")
# Out:
# MSE: 41.47589784373518, R2: 0.7984419131777887

# %%
import matplotlib.pyplot as plt
    
predictions = model.predict(X_test)

plt.scatter(model.predict(X_train), model.predict(X_train) - y_train, c="blue", label="Training Data")
plt.scatter(model.predict(X_test), model.predict(X_test) - y_test, c="orange", label="Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y_test.min(), xmax=y_test.max())
plt.title("Residual Plot")
plt.show()

# %%
guesses = pd.DataFrame({"Predicted": predictions, "Actual": y_test, "Error": predictions - y_test})[["Predicted", "Actual", "Error"]]
guesses
# Out:
#       Predicted  Actual      Error
# 612    1.388094       7  -5.611906
# 628   19.199555      33 -13.800445
# 41    14.427685       6   8.427685
# 687   -1.310362       3  -4.310362
# 615   -9.911647      -7  -2.911647
# 211   -6.793035      -7   0.206965
# 912    3.438143       3   0.438143
# 10    -1.084365       3  -4.084365
# 819    7.415592       3   4.415592
# 1000   2.101143       9  -6.898857
# 61     5.409719       2   3.409719
# 557    5.675522       3   2.675522
# 952   11.804927       7   4.804927
# 442    8.287382      -6  14.287382
# 181   -0.170379     -11  10.829621
# 632    2.829224       3  -0.170776
# 598    4.049250      -2   6.049250
# 398   13.120617      11   2.120617
# 818    2.334275       3  -0.665725
# 573   -3.330986     -17  13.669014
# 693   -6.612236     -13   6.387764
# 715   21.082876      20   1.082876
# 345   -7.048007     -14   6.951993
# 238   -6.807512      -7   0.192488
# 268   23.883403      21   2.883403
# 785   29.199766      41 -11.800234
# ...

# %%
nice = pd.concat([game_data, guesses], axis=1, sort=False)
cleaned = nice[['Year', 'Week', 'HomeTeam', 'AwayTeam', 'HomeScore', 'AwayScore','PointDiff','Predicted','Error','HomeLine']]
games = cleaned.dropna()
games.head()
games.to_csv(path_or_buf='guessesWithTeams.csv')

# %%
from sklearn.externals import joblib
joblib.dump(model, 'John_Madden.joblib')
# Out:
# ['John_Madden.joblib']

# %%
from sklearn.linear_model import Lasso

lasso = Lasso(alpha=.01).fit(X_train, y_train)

predictions = lasso.predict(X_test)

MSE = mean_squared_error(y_test, predictions)
r2 = lasso.score(X_test, y_test)
### END SOLUTION

print(f"MSE: {MSE}, R2: {r2}")
# Out:
# MSE: 46.727424143449255, R2: 0.7316132039154467

# %%
from sklearn.linear_model import Ridge

### BEGIN SOLUTION
ridge = Ridge(alpha=.01).fit(X_train, y_train)

predictions = ridge.predict(X_test)

MSE = mean_squared_error(y_test, predictions)
r2 = ridge.score(X_test, y_test)
### END SOLUTION

print(f"MSE: {MSE}, R2: {r2}")
# Out:
# MSE: 45.3068061317815, R2: 0.7397727616826593

# %%
from sklearn.linear_model import ElasticNet

### BEGIN SOLUTION
elasticnet = ElasticNet(alpha=.01).fit(X_train, y_train)

predictions = elasticnet.predict(X_test)

MSE = mean_squared_error(y_test, predictions)
r2 = elasticnet.score(X_test, y_test)
### END SOLUTION

print(f"MSE: {MSE}, R2: {r2}")
# Out:
# MSE: 45.48674841410246, R2: 0.7387392330104174

# %%
thursX = [[4.5,50.5,-0.1585,0.0125,0.201,-0.16775,-0.06975,0.4765,-0.22075,-0.107,0.076,-0.033]]

# %%
from sklearn.externals import joblib
model=joblib.load('John_Madden.joblib')

# %%
thurs = model.predict(thursX)
thurs
# Out:
# array([-4.28665455])

# %%
from sklearn.svm import SVC 
model = SVC(kernel='linear')

from sklearn.model_selection import GridSearchCV
param_grid = {'C': [ 0.001, 0.01, 0.1, 1, 10, 100, 1000, 10000],
              'gamma': [ 0.00001,0.0001, 0.001, 0.01, 0.1, 1, 10]}
grid = GridSearchCV(model, param_grid, verbose=3)

# %%
grid.fit(X_train, y_train)
# Out:
# C:\Users\Nick\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# C:\Users\Nick\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:652: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=3.
#   % (min_groups, self.n_splits)), Warning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# Fitting 3 folds for each of 56 candidates, totalling 168 fits
# [CV] C=0.001, gamma=1e-05 ............................................
# ...

# %%
from sklearn.externals import joblib
joblib.dump(grid, 'Shotgun.joblib')
# Out:
# ['Shotgun.joblib']

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'C': 0.1, 'gamma': 1e-05}
# 0.08923884514435695

# %%
aoba = grid.predict(thursX)
aoba
# Out:
# array([-3], dtype=int64)

# %%
model2 = SVC(kernel='linear')
param_grid = {'C': [ 0.001, 0.01, 0.1, 1, 10, 100, 1000, 10000],
              'gamma': [ 0.00001,0.0001, 0.001, 0.01, 0.1, 1, 10]}
grid2 = GridSearchCV(model, param_grid, verbose=3, scoring = 'neg_mean_squared_error',n_jobs=-1)

# %%
grid2.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 56 candidates, totalling 168 fits
# C:\Users\Nick\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:652: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=3.
#   % (min_groups, self.n_splits)), Warning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:    4.1s
# [Parallel(n_jobs=-1)]: Done 104 tasks      | elapsed:   10.4s
