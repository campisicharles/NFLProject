# %%
import numpy as np
import pandas as pd
from sklearn.externals import joblib

model1=joblib.load('John_Madden.joblib') 
model2=joblib.load('Shotgun.joblib') 
model3=joblib.load('Pro_Set.joblib') 
model4=joblib.load('Points.joblib') 
game_data = pd.read_csv('Week7&8.csv')
game_data.head()
# Out:
#    Week Home  Away  HomeLine  PredictTotal  HOME_OFFPass_DVOA  \
# 0     7  DEN    KC       4.5          50.5          -0.071833
# 1     7   GB  LARD      -7.0          46.0           0.246333
# 2     7  ATL  LARM       4.0          52.5           0.254333
# 3     7  WAS    SF       9.5          43.0          -0.155833
# 4     7  IND   HOU      -2.5          47.5           0.154200
#
#    HOME_OFFRush_DVOA  HOME_DEFPassDVOA  HOME_DEFRushDVOA  HOME_STDVOA  \
# 0          -0.031833          0.049833         -0.192500    -0.043500
# 1           0.059833         -0.196000         -0.015000     0.002500
# 2          -0.163333          0.544667         -0.185167    -0.040833
# 3          -0.288667          0.185667         -0.015000     0.019500
# 4           0.010800          0.141200          0.029200    -0.034800
#
#    VISIT_OFFPass_DVOA  VISIT_OFFRush_DVOA  VISIT_DEFPassDVOA  \
# 0            0.567167           -0.092000           0.040833
# 1            0.241200            0.071600           0.226400
# 2            0.070667            0.078167           0.166833
# 3            0.155417            0.026667          -0.772583
# 4            0.235833            0.017667           0.033000
#
#    VISIT_DEFRushDVOA  VISIT_STDVOA
# 0           0.055333     -0.010500
# 1          -0.237800     -0.008000
# 2          -0.226500     -0.009667
# 3          -0.144167     -0.036250
# 4          -0.110000     -0.004833

# %%
week7X = game_data[['HomeLine', 'PredictTotal', 'HOME_OFFPass_DVOA', 'HOME_OFFRush_DVOA', 'HOME_DEFPassDVOA', 'HOME_DEFRushDVOA', 'HOME_STDVOA', 'VISIT_OFFPass_DVOA', 'VISIT_OFFRush_DVOA', 'VISIT_DEFPassDVOA', 'VISIT_DEFRushDVOA', 'VISIT_STDVOA']]
diffGuess = model1.predict(week7X)
pointsGuess= model4.predict(week7X)
betGuess = model2.predict(week7X)
classedGuess = model3.predict(week7X)

diffGuess
# Out:
# array([ -8.21143275,   4.21095027,  -6.49663955, -18.09145868,
#         -2.44849225,  -3.15186575,  -7.8467924 ,   1.5565088 ,
#         23.19690123,  -0.96670055,   1.69044412,   0.33140659,
#          0.55041259, -18.72124982])

# %%
week7X
# Out:
#     HomeLine  PredictTotal  HOME_OFFPass_DVOA  HOME_OFFRush_DVOA  \
# 0        4.5          50.5          -0.071833          -0.031833
# 1       -7.0          46.0           0.246333           0.059833
# 2        4.0          52.5           0.254333          -0.163333
# 3        9.5          43.0          -0.155833          -0.288667
# 4       -2.5          47.5           0.154200           0.010800
# 5        0.0          44.0           0.297800          -0.252200
# 6        3.0          47.5          -0.070167          -0.394833
# 7       -3.0          50.0          -0.093667           0.035000
# 8      -15.5          41.0          -0.092600           0.094000
# 9       -1.0          40.5          -0.062333          -0.200333
# 10      -4.0          50.5           0.635833          -0.073667
# 11      -3.0          38.5           0.147400          -0.243600
# 12      -2.5          47.5           0.520600           0.190800
# 13       9.5          43.5          -0.343200          -0.259200
#
#     HOME_DEFPassDVOA  HOME_DEFRushDVOA  HOME_STDVOA  VISIT_OFFPass_DVOA  \
# 0           0.049833         -0.192500    -0.043500            0.567167
# 1          -0.196000         -0.015000     0.002500            0.241200
# 2           0.544667         -0.185167    -0.040833            0.070667
# 3           0.185667         -0.015000     0.019500            0.155417
# 4           0.141200          0.029200    -0.034800            0.235833
# 5           0.001200         -0.069800     0.063000            0.252500
# 6           0.354167          0.019667     0.028667            0.272500
# 7           0.232000         -0.162333    -0.023667            0.009000
# 8          -0.227000         -0.003800    -0.060600           -0.473200
# 9           0.041833         -0.178333    -0.039500            0.227333
# 10          0.058833         -0.038667    -0.039333            0.108333
# 11         -0.061200         -0.254400     0.041600            0.186667
# 12          0.256800         -0.063200    -0.019000            0.268333
# 13          0.091200         -0.182600     0.019000            0.278500
#
#     VISIT_OFFRush_DVOA  VISIT_DEFPassDVOA  VISIT_DEFRushDVOA  VISIT_STDVOA
# 0            -0.092000           0.040833           0.055333     -0.010500
# 1             0.071600           0.226400          -0.237800     -0.008000
# 2             0.078167           0.166833          -0.226500     -0.009667
# 3             0.026667          -0.772583          -0.144167     -0.036250
# 4             0.017667           0.033000          -0.110000     -0.004833
# 5             0.031667          -0.015167          -0.237167      0.001667
# 6            -0.167833           0.056167           0.103167      0.033500
# 7             0.048333           0.320333           0.009167     -0.021333
# 8            -0.411000           0.728200           0.075000     -0.020800
# 9            -0.211667           0.191333          -0.047667      0.009833
# 10            0.211167           0.117500          -0.128000      0.058000
# 11           -0.136833           0.019667          -0.103000      0.066167
# 12           -0.017167           0.164000          -0.261833      0.012500
# 13           -0.050500          -0.636667          -0.250500     -0.012000

# %%
diffGuesses = pd.DataFrame({"Madden Differential": diffGuess, "Over/Under": pointsGuess, "Home Cover?": betGuess, "Class Guess":classedGuess})[["Madden Differential", "Over/Under", "Home Cover?", "Class Guess"]]
diffGuesses
# Out:
#     Madden Differential  Over/Under  Home Cover?  Class Guess
# 0             -8.211433   46.893168            0           -7
# 1              4.210950   47.448353            0            3
# 2             -6.496640   49.486476            1           -3
# 3            -18.091459   37.084758            0          -20
# 4             -2.448492   48.861218            0            3
# 5             -3.151866   44.439773            0            3
# 6             -7.846792   47.713096            0          -14
# 7              1.556509   47.242442            1            3
# 8             23.196901   43.079984            1           25
# 9             -0.966701   40.629693            0           -3
# 10             1.690444   53.107208            0            3
# 11             0.331407   39.908683            0            3
# 12             0.550413   52.310884            0            3
# 13           -18.721250   34.660883            0          -20

# %%
nice = pd.concat([game_data, diffGuesses], axis=1, sort=False)
cleaned = nice[["Home","Away","HomeLine","PredictTotal","Madden Differential", "Over/Under", "Home Cover?", "Class Guess"]]
games = cleaned.dropna()
games.insert(8, "Year", "2019")
games.insert(9, "Week", "7")
games.to_csv(path_or_buf="Week7Predictions.csv", index=False)

# %%
games
# Out:
#    Home  Away  HomeLine  PredictTotal  Madden Differential  Over/Under  \
# 0   DEN    KC       4.5          50.5            -8.211433   46.893168
# 1    GB  LARD      -7.0          46.0             4.210950   47.448353
# 2   ATL  LARM       4.0          52.5            -6.496640   49.486476
# 3   WAS    SF       9.5          43.0           -18.091459   37.084758
# 4   IND   HOU      -2.5          47.5            -2.448492   48.861218
# 5   DET   MIN       0.0          44.0            -3.151866   44.439773
# 6   CIN   JAC       3.0          47.5            -7.846792   47.713096
# 7   NYG   ARI      -3.0          50.0             1.556509   47.242442
# 8   BUF   MIA     -15.5          41.0            23.196901   43.079984
# 9   TEN  LACH      -1.0          40.5            -0.966701   40.629693
# 10  SEA   BAL      -4.0          50.5             1.690444   53.107208
# 11  CHI    NO      -3.0          38.5             0.331407   39.908683
# 12  DAL   PHI      -2.5          47.5             0.550413   52.310884
# 13  NYJ    NE       9.5          43.5           -18.721250   34.660883
#
#     Home Cover?  Class Guess  Year Week
# 0             0           -7  2019    7
# 1             0            3  2019    7
# 2             1           -3  2019    7
# 3             0          -20  2019    7
# 4             0            3  2019    7
# 5             0            3  2019    7
# 6             0          -14  2019    7
# 7             1            3  2019    7
# 8             1           25  2019    7
# 9             0           -3  2019    7
# 10            0            3  2019    7
# 11            0            3  2019    7
# 12            0            3  2019    7
# 13            0          -20  2019    7
