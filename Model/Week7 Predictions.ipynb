# %%
import numpy as np
import pandas as pd
from sklearn.externals import joblib

model1=joblib.load('John_Madden.joblib') 
model2=joblib.load('Shotgun.joblib') 
model3=joblib.load('Pro_Set.joblib') 
model4=joblib.load('Points.joblib') 
game_data = pd.read_csv('Week7&8.csv')
game_data.head()
# Out:
#    Week Home  Away  HomeLine  PredictTotal  HOME_OFFPass_DVOA  \
# 0     7  DEN    KC       4.5          50.5          -0.071833
# 1     7   GB  LARD      -7.0          46.0           0.246333
# 2     7  ATL  LARM       4.0          52.5           0.254333
# 3     7  WAS    SF       9.5          43.0          -0.155833
# 4     7  IND   HOU      -2.5          47.5           0.154200
#
#    HOME_OFFRush_DVOA  HOME_DEFPassDVOA  HOME_DEFRushDVOA  HOME_STDVOA  \
# 0          -0.031833          0.049833         -0.192500    -0.043500
# 1           0.059833         -0.196000         -0.015000     0.002500
# 2          -0.163333          0.544667         -0.185167    -0.040833
# 3          -0.288667          0.185667         -0.015000     0.019500
# 4           0.010800          0.141200          0.029200    -0.034800
#
#    VISIT_OFFPass_DVOA  VISIT_OFFRush_DVOA  VISIT_DEFPassDVOA  \
# 0            0.567167           -0.092000           0.040833
# 1            0.241200            0.071600           0.226400
# 2            0.070667            0.078167           0.166833
# 3            0.155417            0.026667          -0.772583
# 4            0.235833            0.017667           0.033000
#
#    VISIT_DEFRushDVOA  VISIT_STDVOA
# 0           0.055333     -0.010500
# 1          -0.237800     -0.008000
# 2          -0.226500     -0.009667
# 3          -0.144167     -0.036250
# 4          -0.110000     -0.004833

# %%
week7X = game_data[['HomeLine', 'PredictTotal', 'HOME_OFFPass_DVOA', 'HOME_OFFRush_DVOA', 'HOME_DEFPassDVOA', 'HOME_DEFRushDVOA', 'HOME_STDVOA', 'VISIT_OFFPass_DVOA', 'VISIT_OFFRush_DVOA', 'VISIT_DEFPassDVOA', 'VISIT_DEFRushDVOA', 'VISIT_STDVOA']]
diffGuess = model1.predict(week7X)
pointsGuess= model4.predict(week7X)
betGuess = model2.predict(week7X)
classedGuess = model3.predict(week7X)

diffGuess
# Out:
# array([ -8.21143275,   4.21095027,  -6.49663955, -18.09145868,
#         -2.44849225,  -3.15186575,  -7.8467924 ,   1.5565088 ,
#         23.19690123,  -0.96670055,   1.69044412,   0.33140659,
#          0.55041259, -18.72124982])

# %%
diffGuesses = pd.DataFrame({"Madden Differential": diffGuess, "Over/Under": pointsGuess, "Home Cover?": betGuess, "Class Guess":classedGuess})[["Madden Differential", "Over/Under", "Home Cover?", "Class Guess"]]
diffGuesses
# Out:
#     Madden Differential  Over/Under  Home Cover?  Class Guess
# 0             -8.211433   46.893168            0           -7
# 1              4.210950   47.448353            0            3
# 2             -6.496640   49.486476            1           -3
# 3            -18.091459   37.084758            0          -20
# 4             -2.448492   48.861218            0            3
# 5             -3.151866   44.439773            0            3
# 6             -7.846792   47.713096            0          -14
# 7              1.556509   47.242442            1            3
# 8             23.196901   43.079984            1           25
# 9             -0.966701   40.629693            0           -3
# 10             1.690444   53.107208            0            3
# 11             0.331407   39.908683            0            3
# 12             0.550413   52.310884            0            3
# 13           -18.721250   34.660883            0          -20

# %%
nice = pd.concat([game_data, diffGuesses], axis=1, sort=False)
cleaned = nice[["Home","Away","HomeLine","PredictTotal","Madden Differential", "Over/Under", "Home Cover?", "Class Guess"]]
games = cleaned.dropna()
games.to_csv(path_or_buf="Week7Predictions.csv")
